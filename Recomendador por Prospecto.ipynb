# %% [markdown]
# ## Proyecto *Consultoría Técnica de Prospectos*

# %% [markdown]
# ### Agente simple.
#
# Te pide el medicamento deseado y te devuelve el prospecto del primer medicamento con ese nombre de la lista.
#
# No entabla conversación.

# %%
import requests
from bs4 import BeautifulSoup
from groq import Groq
import os

# --- CONFIGURACIÓN ---
# Pon aquí tu API KEY de Groq o configúrala como variable de entorno
import os
from groq import Groq


from dotenv import load_dotenv, find_dotenv

# 1. Cargamos el archivo .env
_ = load_dotenv(find_dotenv()) 

# Asumiendo que guardas tu clave de Groq en el .env como GROQ_API_KEY
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def buscar_medicamento_cima(nombre):
    """
    1. Busca el medicamento en la API de CIMA.
    2. Devuelve el Nro de Registro (nregistro) del primer resultado.
    """
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    params = {"nombre": nombre}
    
    try:
        response = requests.get(url, params=params)
        data = response.json()
        
        if len(data.get("resultados", [])) > 0:
            # Cogemos el primero de la lista (el más relevante)
            primer_resultado = data["resultados"][0]
            nregistro = primer_resultado["nregistro"]
            nombre_oficial = primer_resultado["nombre"]
            print(f"✅ Encontrado: {nombre_oficial} (Reg: {nregistro})")
            return nregistro, nombre_oficial
        else:
            return None, None
            
    except Exception as e:
        print(f"Error conectando con CIMA: {e}")
        return None, None

def obtener_texto_prospecto(nregistro):
    """
    1. Construye la URL del HTML del prospecto.
    2. Descarga y limpia el HTML para obtener solo texto.
    """
    # Patrón de URL oficial de CIMA para prospectos HTML
    url_prospecto = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    
    try:
        response = requests.get(url_prospecto)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Eliminamos scripts y estilos para limpiar
            for script in soup(["script", "style"]):
                script.decompose()
                
            # Extraemos el texto
            texto = soup.get_text(separator="\n")
            
            # Limpieza básica de espacios
            texto_limpio = "\n".join([line.strip() for line in texto.splitlines() if line.strip()])
            return texto_limpio
        else:
            print("❌ No hay prospecto HTML disponible para este registro.")
            return None
    except Exception as e:
        print(f"Error descargando prospecto: {e}")
        return None

def consultar_agente_groq(texto_prospecto, nombre_med):
    """
    Envía el texto a Groq (Llama 3) para procesarlo.
    """
    prompt = f"""
    Eres un asistente farmacéutico experto. Tienes el prospecto oficial del medicamento "{nombre_med}" abajo.
    
    Tu tarea es resumir los puntos clave para un paciente de forma clara y estructurada.
    NO inventes nada. Usa solo la información del texto proporcionado.
    
    Estructura la respuesta así:
    1. ¿Qué es y para qué sirve?
    2. Advertencias importantes.
    3. Cómo tomarlo (Posología resumida).
    4. Efectos secundarios frecuentes.

    --- TEXTO DEL PROSPECTO ---
    {texto_prospecto[:25000]}  # Cortamos por seguridad del contexto, aunque Groq aguanta mucho.
    """

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama-3.3-70b-versatile", # Modelo rápido y potente
        temperature=0.2, # Baja temperatura para ser preciso y no alucinar
    )

    return chat_completion.choices[0].message.content

# --- EJECUCIÓN DEL AGENTE ---
if __name__ == "__main__":
    medicamento_input = input("💊 ¿Qué medicamento buscas?: ")
    
    # Paso 1: Buscar ID
    nregistro, nombre_oficial = buscar_medicamento_cima(medicamento_input)
    
    if nregistro:
        # Paso 2: Obtener Texto
        print("📥 Descargando prospecto...")
        texto_prospecto = obtener_texto_prospecto(nregistro)
        
        if texto_prospecto:
            # Paso 3: Analizar con Groq
            print("🤖 El agente está leyendo el prospecto (vía Groq)...")
            respuesta = consultar_agente_groq(texto_prospecto, nombre_oficial)
            
            print("\n" + "="*40)
            print(f"REPORTE PARA: {nombre_oficial}")
            print("="*40 + "\n")
            print(respuesta)
        else:
            print("No pudimos extraer el texto del prospecto.")
    else:
        print("❌ Medicamento no encontrado en la AEMPS.")
# Out:
# ✅ Encontrado: GRIPPOSTAD CON IBUPROFENO 200 MG/5 MG COMPRIMIDOS RECUBIERTOS CON PELICULA (Reg: 80298)
# 📥 Descargando prospecto...
# 🤖 El agente está leyendo el prospecto (vía Groq)...
#
# ========================================
# REPORTE PARA: GRIPPOSTAD CON IBUPROFENO 200 MG/5 MG COMPRIMIDOS RECUBIERTOS CON PELICULA
# ========================================
#
# **Resumen de puntos clave para un paciente**
#
# 1. **¿Qué es y para qué sirve?**: Grippostad con ibuprofeno es un medicamento que contiene ibuprofeno y hidrocloruro de fenilefrina, indicado para el alivio de los síntomas asociados a gripe y resfriado, como dolor leve o moderado, congestión nasal y fiebre, en adultos y adolescentes mayores de 12 años.
#
# 2. **Advertencias importantes**: No debe tomarse si se es alérgico a los componentes del medicamento, ha tenido úlceras o sangrado gastrointestinal, problemas cardíacos graves, presión arterial alta, trastornos de la coagulación sanguínea, o si se está tomando otros medicamentos que puedan interactuar con Grippostad con ibuprofeno. También es importante consultar con un médico antes de tomar este medicamento si se tiene asma, problemas de riñón, corazón, hígado o intestino, o si se está en los primeros 6 meses de embarazo.
#
# 3. **Cómo tomarlo (Posología resumida)**: Los comprimidos deben ser tragados enteros con agua. La dosis recomendada es de 2 comprimidos cada 8 horas, sin exceder los 6 comprimidos en 24 horas. El tratamiento debe ser a corto plazo, no más de 5 días en adultos y 3 días en adolescentes mayores de 12 años.
#
# 4. **Efectos secundarios frecuentes**: Los efectos secundarios pueden incluir indigestión, acidez, malestar estomacal, dolor de cabeza, mareo, tinnitus (zumbido en los oídos), reacciones alérgicas, como erupciones cutáneas, picor, descamación. Es importante informar a un médico si se experimentan cualquier efecto adverso, especialmente si son graves o persistentes.

# %% [markdown]
# ### Agente Opciones.
#
# Se le añade la condición de elegir entre genérico y de marca.
#
# Te da una lista de los primeros 15 medicamentos de la lista según el nombre y tienes que seleccionar el número que buscas.
#
# El problema es que solo te deja elegir entre los primeros 15 medicamentos unicamente.

# %%
import os
import requests
from bs4 import BeautifulSoup
from groq import Groq
from dotenv import load_dotenv, find_dotenv

# 1. Cargar variables de entorno
load_dotenv(find_dotenv())

# 2. Configurar cliente de Groq con validación
api_key = os.environ.get("GROQ_API_KEY")
if not api_key:
    print("❌ ERROR: No se encontró la GROQ_API_KEY en el archivo .env")
    exit()

client = Groq(api_key=api_key)

def obtener_datos_cima(nombre):
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    params = {"nombre": nombre}
    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status() # Lanza error si la web está caída
        return response.json().get("resultados", [])
    except Exception as e:
        print(f"⚠️ Error conectando con CIMA: {e}")
        return []

def filtrar_por_tipo(resultados, buscar_generico):
    if buscar_generico:
        return [m for m in resultados if "EFG" in m["nombre"].upper()]
    else:
        return [m for m in resultados if "EFG" not in m["nombre"].upper()]

def extraer_texto_prospecto(nregistro):
    # La URL oficial suele ser P_ seguido del número de registro
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url, timeout=10)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            # Limpiamos el texto
            for script in soup(["script", "style"]): script.decompose()
            texto = soup.get_text(separator="\n", strip=True)
            return texto
        return None
    except Exception as e:
        print(f"⚠️ Error al descargar el prospecto: {e}")
        return None

# --- FLUJO DEL CHATBOT ---

print("🤖 Hola, soy tu asistente de prospectos de la AEMPS.")
nombre_input = input("💊 ¿Qué medicamento estás buscando?: ")

resultados_totales = obtener_datos_cima(nombre_input)

if not resultados_totales:
    print("❌ No he encontrado resultados.")
else:
    print(f"\n✅ He encontrado {len(resultados_totales)} opciones.")
    tipo = input("❓ ¿Buscas el genérico (si) o de marca (no)?: ").strip().lower()
    
    es_generico = True if tipo == "si" else False
    opciones = filtrar_por_tipo(resultados_totales, es_generico)
    
    if not opciones:
        print(f"No hay opciones para esa categoría.")
    else:
        print(f"\n--- PRESENTACIONES DISPONIBLES ---")
        for i, med in enumerate(opciones[:15]):
            print(f"{i+1}. {med['nombre']}")
        
        try:
            seleccion = int(input("\nEscribe el número elegido: ")) - 1
            if 0 <= seleccion < len(opciones):
                med_elegido = opciones[seleccion]
                print(f"🔍 Obteniendo prospecto de: {med_elegido['nombre']}...")
                
                texto_prospecto = extraer_texto_prospecto(med_elegido['nregistro'])
                
                if texto_prospecto and len(texto_prospecto) > 200:
                    print("🤖 Groq está analizando el texto...")
                    
                    # LLAMADA A GROQ
                    try:
                        completion = client.chat.completions.create(
                            messages=[
                                {"role": "system", "content": "Eres un farmacéutico experto. Resume el prospecto en: 1-Para qué sirve, 2-Cómo tomar, 3-Efectos secundarios graves. Sé breve."},
                                {"role": "user", "content": f"Prospecto:\n\n{texto_prospecto[:12000]}"}
                            ],
                            model="llama-3.3-70b-versatile",
                            temperature=0.1
                        )
                        print("\n" + "="*50)
                        print(completion.choices[0].message.content)
                        print("="*50)
                    except Exception as e:
                        print(f"❌ Error en Groq: {e}")
                else:
                    print("⚠️ Este medicamento no tiene prospecto en formato texto (probablemente solo PDF).")
            else:
                print("Selección fuera de rango.")
        except ValueError:
            print("Introduce un número válido.")
# Out:
# 🤖 Hola, soy tu asistente de prospectos de la AEMPS.
#
# ✅ He encontrado 141 opciones.
#
# --- PRESENTACIONES DISPONIBLES ---
# 1. IBUPROFENO (ARGININA) CINFA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 2. IBUPROFENO (ARGININA) KERN PHARMA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 3. IBUPROFENO (ARGININA) NORMON 400 mg GRANULADO PARA SOLUCION ORAL EFG
# 4. IBUPROFENO (ARGININA) NORMON 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 5. IBUPROFENO (ARGININA) SANDOZ 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 6. IBUPROFENO (ARGININA) STADA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 7. IBUPROFENO CINFA 20 MG/ML SUSPENSIÓN ORAL EFG
# 8. IBUPROFENO CINFA 40 MG/ML SUSPENSION ORAL EFG
# 9. IBUPROFENO CINFA 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 10. IBUPROFENO CINFAMED 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 11. IBUPROFENO NORMON 20 mg/ml SUSPENSION ORAL EFG
# 12. IBUPROFENO NORMON 40 mg/ml SUSPENSION ORAL EFG
# 13. IBUPROFENO NORMON 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 14. IBUPROFENO NORMON 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 15. IBUPROFENO SANDOZ 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 🔍 Obteniendo prospecto de: IBUPROFENO (ARGININA) KERN PHARMA 600 mg GRANULADO PARA SOLUCION ORAL EFG...
# 🤖 Groq está analizando el texto...
#
# ==================================================
# A continuación, te presento un resumen del prospecto en 3 puntos:
#
# 1. **Para qué sirve**: El ibuprofeno (arginina) es un medicamento antiinflamatorio no esteroideo (AINE) utilizado para tratar la fiebre, el dolor de intensidad leve o moderada (incluyendo la migraña), la artritis, la artritis reumatoide juvenil, la artrosis, la espondilitis anquilosante, la inflamación no reumática y la dismenorrea primaria.
#
# 2. **Cómo tomar**: Es importante leer el prospecto detenidamente y seguir las instrucciones del médico o farmacéutico. Debe tomarse la dosis más pequeña que alivie o controle el dolor y no debe tomarse más tiempo del necesario para controlar los síntomas. Es importante informar al médico sobre cualquier condición médica preexistente, como problemas de corazón, riñones o hígado, y sobre la toma de otros medicamentos.
#
# 3. **Efectos secundarios graves**: Puede producir reacciones alérgicas graves, como dermatitis exfoliativa, eritema multiforme, síndrome de Stevens-Johnson, necrólisis epidérmica tóxica, reacción a fármacos con eosinofilia y síntomas sistémicos (síndrome DRESS), pustulosis exantemática generalizada aguda (PEGA). También puede aumentar el riesgo de sufrir un ataque al corazón o un ictus, especialmente cuando se utiliza en dosis altas. Es importante interrumpir el tratamiento y buscar atención médica inmediatamente si se presentan síntomas graves.
# ==================================================

# %% [markdown]
# ### Agente Abierto.
#
# Al anterior se le añade que puedes poner un medicamento que no está en la lista.
#
# El chatbot presenta grandes limitaciones para parar la conversación.

# %%
import os
import requests
import time
from bs4 import BeautifulSoup
from groq import Groq
from dotenv import load_dotenv, find_dotenv

# --- CONFIGURACIÓN ---
load_dotenv(find_dotenv())
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def buscar_en_cima(nombre):
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    params = {"nombre": nombre, "tamanioPagina": 50}
    try:
        response = requests.get(url, params=params, timeout=10)
        if response.status_code == 200:
            return response.json().get("resultados", [])
    except:
        return []
    return []

def extraer_texto_prospecto(nregistro):
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url, timeout=10)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            # Limpieza de HTML para no saturar a la IA
            for tag in soup(["script", "style", "header", "footer", "nav"]):
                tag.decompose()
            return soup.get_text(separator="\n", strip=True)
    except:
        return None

def chatbot():
    print("\n" + "="*40)
    print("🤖 ASISTENTE MÉDICO ACTIVO")
    print("="*40)

    while True:
        # PASO 1: Búsqueda inicial
        query = input("\n💊 ¿Qué medicamento buscas? (o 'salir'): ").strip()
        if query.lower() == 'salir': break
        
        resultados = buscar_en_cima(query)
        if not resultados:
            print(f"❌ No hay resultados para '{query}'.")
            continue

        # PASO 2: Filtro Marca/Genérico
        tipo = input(f"🔍 He encontrado opciones. ¿Quieres GENÉRICO (si) o MARCA (no)?: ").lower().strip()
        es_generico = True if tipo == 'si' else False
        
        if es_generico:
            opciones = [m for m in resultados if "EFG" in m["nombre"].upper()]
        else:
            opciones = [m for m in resultados if "EFG" not in m["nombre"].upper()]

        if not opciones:
            print("⚠️ No hay opciones en esa categoría. Mostrando todos los resultados encontrados...")
            opciones = resultados[:20]
        else:
            opciones = opciones[:20]

        # PASO 3: Mostrar Lista y Selección
        print(f"\n--- 📋 LISTA DE OPCIONES ---")
        for i, m in enumerate(opciones, 1):
            print(f"{i}. {m['nombre']}")
        
        print("\n💡 Escribe el NÚMERO o el NOMBRE del medicamento deseado.")
        seleccion = input("👉 Selección: ").strip()

        # Determinar qué eligió el usuario
        med_final = None

        # ¿Es un número?
        if seleccion.isdigit():
            idx = int(seleccion) - 1
            if 0 <= idx < len(opciones):
                med_final = opciones[idx]
        
        # ¿Es un nombre? (Buscamos si lo que escribió está en la lista)
        if not med_final:
            for m in opciones:
                if seleccion.upper() in m['nombre'].upper():
                    med_final = m
                    break
        
        # PASO 4: Procesar Prospecto
        if med_final:
            print(f"\n📥 Cargando prospecto de: {med_final['nombre']}...")
            texto = extraer_texto_prospecto(med_final['nregistro'])
            
            if texto and len(texto) > 100:
                print("🤖 Groq analizando... (Llama 3.3)")
                try:
                    resumen = client.chat.completions.create(
                        messages=[
                            {"role": "system", "content": "Eres un farmacéutico. Resume el prospecto en: 1. Uso, 2. Dosis y 3. Alertas."},
                            {"role": "user", "content": f"Prospecto de {med_final['nombre']}:\n\n{texto[:12000]}"}
                        ],
                        model="llama-3.3-70b-versatile",
                        temperature=0.2
                    )
                    print("\n" + "—"*50)
                    print(resumen.choices[0].message.content)
                    print("—"*50)
                except Exception as e:
                    print(f"❌ Error en Groq: {e}")
            else:
                print("⚠️ Este medicamento no tiene prospecto en texto disponible.")
        else:
            print(f"🔄 No entendí tu elección, reiniciando búsqueda para '{seleccion}'...")
            # Aquí está el truco: si no eligió número ni nombre de la lista, 
            # usamos 'seleccion' como la nueva búsqueda para el siguiente ciclo.
            # Pero para que funcione, simplemente dejamos que el bucle siga.

if __name__ == "__main__":
    chatbot()
# Out:
# ========================================
# 🤖 ASISTENTE MÉDICO ACTIVO
# ========================================
#
# --- 📋 LISTA DE OPCIONES ---
# 1. IBUPROFENO (ARGININA) CINFA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 2. IBUPROFENO (ARGININA) KERN PHARMA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 3. IBUPROFENO (ARGININA) NORMON 400 mg GRANULADO PARA SOLUCION ORAL EFG
# 4. IBUPROFENO (ARGININA) NORMON 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 5. IBUPROFENO (ARGININA) SANDOZ 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 6. IBUPROFENO (ARGININA) STADA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 7. IBUPROFENO CINFA 20 MG/ML SUSPENSIÓN ORAL EFG
# 8. IBUPROFENO CINFA 40 MG/ML SUSPENSION ORAL EFG
# 9. IBUPROFENO CINFA 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 10. IBUPROFENO CINFAMED 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 11. IBUPROFENO NORMON 20 mg/ml SUSPENSION ORAL EFG
# 12. IBUPROFENO NORMON 40 mg/ml SUSPENSION ORAL EFG
# 13. IBUPROFENO NORMON 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 14. IBUPROFENO NORMON 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 15. IBUPROFENO SANDOZ 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 16. IBUPROFENO STADA 400 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 17. IBUPROFENO STADA 600 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 18. IBUPROFENO TARBIS 600 mg COMPRIMIDOS RECUBIERTOS CON PELÍCULA EFG
# 19. DEXIBUPROFENO STRIDES 200 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 20. DEXIBUPROFENO STRIDES 300 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
#
# 💡 Escribe el NÚMERO o el NOMBRE del medicamento deseado.
#
# 📥 Cargando prospecto de: DEXIBUPROFENO STRIDES 300 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG...
# 🤖 Groq analizando... (Llama 3.3)
#
# ——————————————————————————————————————————————————
# A continuación, te presento un resumen del prospecto en 3 puntos clave:
#
# **1. Uso**
# El medicamento Dexibuprofeno Strides se utiliza para aliviar:
# * Dolor e inflamación causados por la artrosis
# * Dolor del período menstrual
# * Dolor de leve a moderado, como el dolor muscular y articular o el dolor dental
#
# **2. Dosis**
# La dosis recomendada no se especifica en el texto proporcionado, pero se menciona que se debe seguir exactamente las instrucciones de administración indicadas por el médico o farmacéutico. Se recomienda tomar el medicamento con un vaso de agua u otro líquido, y se puede tomar con o sin alimentos, aunque se recomienda tomarlo con alimentos para reducir la posibilidad de problemas gástricos.
#
# **3. Alertas**
# Se deben tener en cuenta las siguientes alertas:
# * No tomar el medicamento si se es alérgico al dexibuprofeno o a alguno de los componentes del medicamento
# * No tomar el medicamento si se ha padecido hemorragia o perforación gastrointestinal originada por algún AINE
# * No tomar el medicamento si se padece insuficiencia cardiaca grave, enfermedad grave de los riñones o del hígado, o si se está en el tercer trimestre de embarazo
# * Se deben tener en cuenta las interacciones con otros medicamentos, como anticoagulantes, medicamentos para la presión arterial alta, litio, metotrexato, etc.
# * Se deben limitar o evitar la ingesta de alcohol mientras se toma el medicamento
# * Se deben tener en cuenta los efectos adversos posibles, como problemas gastrointestinales, reacciones alérgicas, etc.
# ——————————————————————————————————————————————————
#
# --- 📋 LISTA DE OPCIONES ---
# 1. IBUPROFENO (ARGININA) CINFA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 2. IBUPROFENO (ARGININA) KERN PHARMA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 3. IBUPROFENO (ARGININA) NORMON 400 mg GRANULADO PARA SOLUCION ORAL EFG
# 4. IBUPROFENO (ARGININA) NORMON 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 5. IBUPROFENO (ARGININA) SANDOZ 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 6. IBUPROFENO (ARGININA) STADA 600 mg GRANULADO PARA SOLUCION ORAL EFG
# 7. IBUPROFENO CINFA 20 MG/ML SUSPENSIÓN ORAL EFG
# 8. IBUPROFENO CINFA 40 MG/ML SUSPENSION ORAL EFG
# 9. IBUPROFENO CINFA 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 10. IBUPROFENO CINFAMED 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 11. IBUPROFENO NORMON 20 mg/ml SUSPENSION ORAL EFG
# 12. IBUPROFENO NORMON 40 mg/ml SUSPENSION ORAL EFG
# 13. IBUPROFENO NORMON 400 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 14. IBUPROFENO NORMON 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 15. IBUPROFENO SANDOZ 600 mg COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 16. IBUPROFENO STADA 400 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 17. IBUPROFENO STADA 600 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 18. IBUPROFENO TARBIS 600 mg COMPRIMIDOS RECUBIERTOS CON PELÍCULA EFG
# 19. DEXIBUPROFENO STRIDES 200 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
# 20. DEXIBUPROFENO STRIDES 300 MG COMPRIMIDOS RECUBIERTOS CON PELICULA EFG
#
# 💡 Escribe el NÚMERO o el NOMBRE del medicamento deseado.
# 🔄 No entendí tu elección, reiniciando búsqueda para '21'...
#
# --- 📋 LISTA DE OPCIONES ---
# 1. A.A.S. 100 mg COMPRIMIDOS
# 2. A.A.S. 500 mg COMPRIMIDOS
# 3. ABRAXANE 5 MG/ML POLVO PARA DISPERSION PARA PERFUSION
# 4. ABRYSVO POLVO Y DISOLVENTE PARA SOLUCION INYECTABLE
# 5. ABSORCOL 10 mg COMPRIMIDOS
# 6. ACABEL RAPID 8 mg COMPRIMIDOS RECUBIERTOS CON PELICULA
# 7. ACABEL 4 mg COMPRIMIDOS RECUBIERTOS CON PELICULA
# 8. ACABEL 8 mg COMPRIMIDOS RECUBIERTOS CON PELICULA
# 9. ACALKA 1080 mg COMPRIMIDOS DE LIBERACION PROLONGADA
# 10. ACARBOSA TECNIGEN 100 mg COMPRIMIDOS
# 11. ACARBOSA TECNIGEN 50 mg COMPRIMIDOS
# 12. ACEOTO PLUS 3 mg/ml + 0,25 mg/ml GOTAS ÓTICAS EN SOLUCIÓN
# 13. ACEOTO 3 MG/ML GOTAS ÓTICAS EN SOLUCIÓN
# 14. ACETILCISTEINA SANDOZ CARE 200 mg POLVO PARA SOLUCIÓN ORAL
# 15. ACETILCISTEINA SANDOZ CARE 600 mg COMPRIMIDOS EFERVESCENTES
# 16. ACETILCOLINA 10 MG/ML CUSÍ POLVO Y DISOLVENTE PARA SOLUCIÓN PARA INSTILACIÓN POR VÍA INTRAOCULAR
# 17. ACICLOVIR SANDOZ CARE 50 MG/G CREMA
# 18. ACICLOVIR STADA 50 MG/G CREMA
# 19. ACIDO ACETILSALICILICO TECNIGEN 100 MG COMPRIMIDOS GASTRORRESISTENTES
# 20. ACOXXEL 120 mg COMPRIMIDOS RECUBIERTOS CON PELICULA
#
# 💡 Escribe el NÚMERO o el NOMBRE del medicamento deseado.
#
# 📥 Cargando prospecto de: A.A.S. 100 mg COMPRIMIDOS...
# 🤖 Groq analizando... (Llama 3.3)
#
# ——————————————————————————————————————————————————
# **Resumen del Prospecto de A.A.S. 100 mg COMPRIMIDOS**
#
# ### 1. Uso
#
# A.A.S. 100 mg está indicado para prevenir la formación de trombos y reducir el riesgo de obstrucción de las arterias en pacientes que han sufrido:
# - Un infarto de miocardio o una angina de pecho.
# - Un accidente cerebrovascular no hemorrágico transitorio o permanente.
# - Una intervención quirúrgica, como angioplastia coronaria o by-pass coronario.
#
# ### 2. Dosis
#
# La dosis recomendada no se especifica en el texto proporcionado, pero se menciona que no se debe tomar más de 100 mg/día en el tercer trimestre de embarazo. Es importante seguir las instrucciones del médico o farmacéutico para la dosificación adecuada.
#
# ### 3. Alertas
#
# **Contraindicaciones:**
# - Alergia al ácido acetilsalicílico o a componentes del medicamento.
# - Mastocitosis.
# - Úlcera gástrica, duodenal o molestias gástricas de repetición.
# - Reacciones alérgicas de tipo asmático.
# - Asma o pólipos nasales asociados con asma.
# - Hemofilia u otros problemas de coagulación sanguínea.
# - Tratamiento con anticoagulantes orales o metotrexato a dosis superiores a 20 mg/semana.
# - Insuficiencia hepática grave.
# - Insuficiencia renal grave.
# - Insuficiencia cardíaca grave e incontrolada.
# - Menos de 16 años sin indicación médica expresa.
# - Tercer trimestre de embarazo a dosis superiores a 100 mg/día.
#
# **Advertencias y Precauciones:**
# - Enfermedades del riñón, corazón o hígado.
# - Insuficiencia hepática leve o moderada.
# - Alteraciones en la coagulación sanguínea.
# - Gota.
# - Hemorragia del útero o menorragias.
# - Intervención quirúrgica, incluyendo cirugía dental.
# - Vacunación reciente.
# - Rinitis y/o urticaria.
# - Deficiencia de glucosa-6-fosfato deshidrogenasa.
# - Uso de levotiroxina y salicilatos.
# - Uso de antiinflamatorios o otros medicamentos.
# - Hipertensión.
# - Consumo de alcohol.
#
# **Interacciones con Otros Medicamentos:**
# - Medicamentos para evitar el rechazo de trasplantes.
# - Medicamentos para la presión arterial alta.
# - Metotrexato.
# - Otros analgésicos o antiinflamatorios no esteroideos.
# - Anticoagulantes, trombolíticos, antiagregantes plaquetarios.
# - Medicamentos que disminuyen el nivel de azúcar en sangre.
# - Barbitúricos.
# - Corticoides.
# - Cimetidina y ranitidina.
# - Digoxina.
# - Fenitoína y ácido valproico.
# - Litio e inhibidores del receptor de serotonina.
# - Probenecid y sulfinpirazona.
# - Vancomicina y sulfamidas.
# - Interferón alfa.
# - Zidovudina.
# - Metamizol.
# - Acetazolamida.
# - Vacuna de la varicela.
# - Levotiroxina.
# - Tenofovir.
# - Nicorandil.
# - Pemetrexed.
# - Alcohol.
#
# Es crucial leer el prospecto completo y consultar con un médico o farmacéutico antes de iniciar el tratamiento con A.A.S. 100 mg, especialmente si se tienen condiciones de salud preexistentes o se están tomando otros medicamentos.
# ——————————————————————————————————————————————————

# %% [markdown]
# ### Agente Prospecto.
#
# El chatbot es mucho más preciso y elaborado; pones el medicamento y tienes la opción de genérico o de marca como seleccionar opciones en el propio chat.
#
# Te da una lista para abrir con todas las opciones y te devuelve el prospecto.

# %%
import panel as pn
import os
import requests
from bs4 import BeautifulSoup
from groq import Groq
from dotenv import load_dotenv

load_dotenv()
pn.extension() # Esto es vital para que se vea en el cuaderno


# Configuración del cliente
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# --- LÓGICA DE BACKEND ---
def buscar_medicamentos(nombre):
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    r = requests.get(url, params={"nombre": nombre, "tamanioPagina": 50})
    return r.json().get("resultados", [])

def obtener_prospecto(nregistro):
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    r = requests.get(url)
    if r.status_code == 200:
        soup = BeautifulSoup(r.content, 'html.parser')
        for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
        return soup.get_text(separator="\n", strip=True)[:12000]
    return None

# --- COMPONENTES DE LA INTERFAZ ---
input_med = pn.widgets.TextInput(name="1. Busca el nombre", placeholder="Ej: Paracetamol")
btn_buscar = pn.widgets.Button(name="🔍 Buscar", button_type="primary")
radio_tipo = pn.widgets.RadioBoxGroup(name="Tipo", options=["Marca", "Genérico (EFG)"], inline=True)
selector_med = pn.widgets.Select(name="2. Elige la presentación", options=[])
btn_resumen = pn.widgets.Button(name="🤖 Generar Resumen", button_type="success", disabled=True)
output_panel = pn.pane.Markdown("Esperando búsqueda...", width=600, styles={'background': '#f9f9f9', 'padding': '15px'})

# --- FUNCIONES DE INTERACCIÓN ---
resultados_cache = []

def actualizar_busqueda(event):
    global resultados_cache
    output_panel.object = "⏳ Buscando en CIMA..."
    resultados_cache = buscar_medicamentos(input_med.value)
    
    if not resultados_cache:
        output_panel.object = "❌ No se encontraron resultados."
        return

    # Filtrar según el radio botón
    es_generico = "EFG" if radio_tipo.value == "Genérico (EFG)" else ""
    if es_generico:
        filtrados = [m for m in resultados_cache if "EFG" in m['nombre'].upper()]
    else:
        filtrados = [m for m in resultados_cache if "EFG" not in m['nombre'].upper()]
    
    selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados[:]}
    btn_resumen.disabled = False
    output_panel.object = f"✅ Encontrados {len(filtrados)} resultados. Ahora elige uno en el desplegable."

def generar_resumen(event):
    nreg = selector_med.value
    nombre = selector_med.labels[0] if selector_med.labels else "medicamento"
    output_panel.object = f"📥 Leyendo prospecto de {nombre}..."
    
    texto = obtener_prospecto(nreg)
    if texto:
        try:
            res = client.chat.completions.create(
                messages=[
                    {"role": "system", "content": "Eres un farmacéutico. Resume: 1. Uso, 2. Dosis, 3. Alertas."},
                    {"role": "user", "content": f"Prospecto:\n\n{texto}"}
                ],
                model="llama-3.3-70b-versatile",
                temperature=0.2
            )
            output_panel.object = f"### Resumen de {nombre}\n\n" + res.choices[0].message.content
        except Exception as e:
            output_panel.object = f"❌ Error en Groq: {str(e)}"
    else:
        output_panel.object = "⚠️ No hay prospecto en texto para este medicamento."

btn_buscar.on_click(actualizar_busqueda)
btn_resumen.on_click(generar_resumen)

# --- RENDERIZADO EN EL CUADERNO ---
layout = pn.Column(
    "# 💊 Buscador Paso a Paso",
    pn.Row(input_med, btn_buscar),
    pn.Row("Filtrar por:", radio_tipo),
    selector_med,
    btn_resumen,
    "---",
    output_panel
)

layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7b42505b-24b1-4bd1-8131-baa3372ce117'>
#   <div id="cf146402-fc0d-4889-aea1-f609b7eb556e" data-root-id="7b42505b-24b1-4bd1-8131-baa3372ce117" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f258dea5-774d-4b9e-a720-29de667c76f4":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"f3c25c29-2a38-4952-a422-500228efe95f","attributes":{"notifications":{"type":"object","name":"Notifications","id":"1b0daa81-2858-4659-993d-f13f4c69883b"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7b42505b-24b1-4bd1-8131-baa3372ce117"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1cc4a867-13aa-4215-a5e8-ddd12f1cfb9d","attributes":{"plot_id":"7b42505b-24b1-4bd1-8131-baa3372ce117","comm_id":"bd5f3316900c4cf596f66d8a680b8cb1","client_comm_id":"8c5865b421984e03b62f2deea304e29b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"f258dea5-774d-4b9e-a720-29de667c76f4","roots":{"7b42505b-24b1-4bd1-8131-baa3372ce117":"cf146402-fc0d-4889-aea1-f609b7eb556e"},"root_ids":["7b42505b-24b1-4bd1-8131-baa3372ce117"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'d624ee3c-9f55-4c7e-9d3b-6811b5b58d88': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto simple.
#
# Como el anterior pero te permite hacer consultas sobre el medicamento seleccionado.
#
# Te devuelve una respuesta a tu consulta sobre la cuestión planteada en función de lo que pone en el prospecto.

# %%
import panel as pn
import os
import requests
from bs4 import BeautifulSoup
from groq import Groq
from dotenv import load_dotenv

load_dotenv()
pn.extension() 

# Configuración del cliente
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# --- LÓGICA DE BACKEND ---
def buscar_medicamentos(nombre):
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    try:
        r = requests.get(url, params={"nombre": nombre, "tamanioPagina": 50})
        return r.json().get("resultados", [])
    except:
        return []

def obtener_prospecto(nregistro):
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:12000]
    except:
        return None

# --- COMPONENTES DE LA INTERFAZ ---
input_med = pn.widgets.TextInput(name="1. Busca el nombre del medicamento", placeholder="Ej: Ibuprofeno")
btn_buscar = pn.widgets.Button(name="🔍 Buscar en CIMA", button_type="primary")
radio_tipo = pn.widgets.RadioBoxGroup(name="Filtrar por tipo", options=["Marca", "Genérico (EFG)"], inline=True)

selector_med = pn.widgets.Select(name="2. Elige la presentación exacta", options=[])

# NUEVOS COMPONENTES PARA LA PREGUNTA
input_pregunta = pn.widgets.TextInput(
    name="3. Haz tu pregunta específica sobre este medicamento", 
    placeholder="Ej: Tengo 22 años y peso 80kg, ¿cuánta dosis debo tomar?"
)
btn_preguntar = pn.widgets.Button(name="💬 Consultar al Agente", button_type="success", disabled=True)

output_panel = pn.pane.Markdown("Esperando búsqueda...", width=600, styles={'background': '#f9f9f9', 'padding': '15px', 'border': '1px solid #ddd'})

# --- FUNCIONES DE INTERACCIÓN ---
resultados_cache = []

def actualizar_busqueda(event):
    global resultados_cache
    output_panel.object = "⏳ Buscando opciones..."
    resultados_cache = buscar_medicamentos(input_med.value)
    
    if not resultados_cache:
        output_panel.object = "❌ No se encontraron resultados."
        return

    es_generico = "EFG" if radio_tipo.value == "Genérico (EFG)" else ""
    if es_generico:
        filtrados = [m for m in resultados_cache if "EFG" in m['nombre'].upper()]
    else:
        filtrados = [m for m in resultados_cache if "EFG" not in m['nombre'].upper()]
    
    selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados[:]}
    
    if filtrados:
        btn_preguntar.disabled = False
        output_panel.object = f"✅ Encontrados {len(filtrados)} resultados.\n\n**Selecciona uno y escribe tu pregunta abajo.**"
    else:
        output_panel.object = "⚠️ No hay resultados para ese tipo (Marca/Genérico)."

def atender_consulta(event):
    if not input_pregunta.value:
        output_panel.object = "⚠️ Por favor, escribe una pregunta primero."
        return

    nreg = selector_med.value
    nombre = selector_med.labels[0] if selector_med.labels else "medicamento"
    pregunta = input_pregunta.value
    
    output_panel.object = f"⏳ **Consultando prospecto de {nombre}...**"
    
    texto_prospecto = obtener_prospecto(nreg)
    
    if texto_prospecto:
        try:
            # PROMPT PERSONALIZADO PARA RESPONDER PREGUNTAS
            prompt_sistema = (
                "Eres un asistente farmacéutico experto. Tienes acceso al prospecto oficial de un medicamento. "
                "Tu objetivo es responder de forma precisa y segura a la pregunta del usuario basándote únicamente en el texto proporcionado. "
                "Si el prospecto no menciona la dosis para un peso o edad específicos, indícalo claramente y recomienda consultar a un médico."
            )
            
            res = client.chat.completions.create(
                messages=[
                    {"role": "system", "content": prompt_sistema},
                    {"role": "user", "content": f"PREGUNTA: {pregunta}\n\nPROSPECTO:\n{texto_prospecto}"}
                ],
                model="llama-3.3-70b-versatile",
                temperature=0.1 # Temperatura baja para mayor precisión técnica
            )
            
            output_panel.object = f"### Respuesta sobre {nombre}:\n\n" + res.choices[0].message.content
        except Exception as e:
            output_panel.object = f"❌ Error en la IA: {str(e)}"
    else:
        output_panel.object = "⚠️ No se pudo cargar el prospecto de este medicamento."

btn_buscar.on_click(actualizar_busqueda)
btn_preguntar.on_click(atender_consulta)

# --- RENDERIZADO ---
layout = pn.Column(
    "# 💊 Consultoría Técnica de Prospectos",
    pn.Row(input_med, btn_buscar),
    pn.Row("Filtrar por:", radio_tipo),
    selector_med,
    "---",
    input_pregunta,
    btn_preguntar,
    "---",
    output_panel
)

layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='44a0f8a4-568a-452c-bd40-ef25fb11fd95'>
#   <div id="f4342a5c-4fd8-4e59-a549-9540ef55caae" data-root-id="44a0f8a4-568a-452c-bd40-ef25fb11fd95" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"42b5437d-fe66-4ae2-92bc-a722126ae00e":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"2baaba9e-865c-443e-bd15-467d5aaefd5c","attributes":{"notifications":{"type":"object","name":"Notifications","id":"4ebeaa09-99e3-4fe4-9de3-827b374bd150"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"44a0f8a4-568a-452c-bd40-ef25fb11fd95"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"7f6404a4-40ea-4802-8456-5d95b60289ef","attributes":{"plot_id":"44a0f8a4-568a-452c-bd40-ef25fb11fd95","comm_id":"7ca3eb624a784bbe8eff344e1b229c54","client_comm_id":"68bff169bfec4e63bc661b47df782b29"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"42b5437d-fe66-4ae2-92bc-a722126ae00e","roots":{"44a0f8a4-568a-452c-bd40-ef25fb11fd95":"f4342a5c-4fd8-4e59-a549-9540ef55caae"},"root_ids":["44a0f8a4-568a-452c-bd40-ef25fb11fd95"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'6ae04432-c472-4a7f-b1c4-ff711f3e8143': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto Definitvo.
#
# Como el anterior pero CON MEMORIA.
#
# Se puede entablar conversación con el agente.

# %%
import panel as pn
import os
import requests
from bs4 import BeautifulSoup
from groq import Groq
from dotenv import load_dotenv

load_dotenv()
pn.extension() 

# Configuración del cliente
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

# --- LÓGICA DE BACKEND ---
def buscar_medicamentos(nombre):
    url = "https://cima.aemps.es/cima/rest/medicamentos"
    try:
        r = requests.get(url, params={"nombre": nombre, "tamanioPagina": 50})
        return r.json().get("resultados", [])
    except: return []

def obtener_prospecto(nregistro):
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:12000]
    except: return None

# --- VARIABLES DE MEMORIA ---
historial_mensajes = [] # Aquí guardaremos la conversación
texto_prospecto_actual = ""

# --- COMPONENTES DE LA INTERFAZ ---
input_med = pn.widgets.TextInput(name="1. Busca el medicamento", placeholder="Ej: Ibuprofeno")
btn_buscar = pn.widgets.Button(name="🔍 Buscar", button_type="primary", width=100)
radio_tipo = pn.widgets.RadioBoxGroup(options=["Marca", "Genérico (EFG)"], inline=True)
selector_med = pn.widgets.Select(name="2. Elige presentación", options=[])

# CHAT INTERACTIVO
chat_display = pn.Column(height=400, scroll=True, styles={'background': '#ffffff', 'border': '1px solid #eee', 'padding': '10px'})
input_pregunta = pn.widgets.TextInput(placeholder="Haz una pregunta sobre el prospecto...", width=450)
btn_preguntar = pn.widgets.Button(name="💬 Enviar", button_type="success", disabled=True)
btn_borrar_memoria = pn.widgets.Button(name="🗑️ Borrar chat", button_type="warning", width=100)

status = pn.pane.Markdown("*Esperando búsqueda...*")

# --- FUNCIONES DE INTERACCIÓN ---

def actualizar_busqueda(event):
    global historial_mensajes
    status.object = "⏳ Buscando..."
    res = buscar_medicamentos(input_med.value)
    
    es_generico = "EFG" if radio_tipo.value == "Genérico (EFG)" else ""
    filtrados = [m for m in res if (es_generico in m['nombre'].upper())] if es_generico else [m for m in res if "EFG" not in m['nombre'].upper()]
    
    selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados[:]}
    if filtrados:
        btn_preguntar.disabled = False
        status.object = "✅ Medicamento cargado. ¡Ya puedes chatear con su prospecto!"
        # Al cambiar de medicamento, reseteamos el chat para no mezclar prospectos
        borrar_chat(None)
    else:
        status.object = "❌ No hay resultados."

def borrar_chat(event):
    global historial_mensajes
    historial_mensajes = []
    chat_display.clear()
    chat_display.append(pn.pane.Markdown("_Memoria del chat vacía._"))

def atender_chat(event):
    global historial_mensajes, texto_prospecto_actual
    pregunta = input_pregunta.value
    if not pregunta: return
    
    input_pregunta.value = "" # Limpiar caja
    chat_display.append(pn.pane.Markdown(f"👤 **Tú:** {pregunta}"))
    
    nreg = selector_med.value
    nombre = selector_med.labels[0]
    
    # Solo descargamos el prospecto si no lo tenemos ya en memoria para ahorrar tiempo
    texto_prospecto_actual = obtener_prospecto(nreg)
    
    if texto_prospecto_actual:
        try:
            # Construimos el contexto para Groq
            mensajes_para_ia = [
                {"role": "system", "content": f"Eres un farmacéutico experto con el prospecto de {nombre}. Responde basándote en el texto. Usa la memoria para seguir el hilo."},
                {"role": "user", "content": f"CONTEXTO (Prospecto):\n{texto_prospecto_actual}"}
            ]
            
            # Añadimos el historial previo
            for msg in historial_mensajes:
                mensajes_para_ia.append(msg)
            
            # Añadimos la pregunta actual
            mensajes_para_ia.append({"role": "user", "content": pregunta})
            
            res = client.chat.completions.create(
                messages=mensajes_para_ia,
                model="llama-3.3-70b-versatile",
                temperature=0.2
            )
            
            respuesta_ia = res.choices[0].message.content
            
            # Guardamos en la memoria real
            historial_mensajes.append({"role": "user", "content": pregunta})
            historial_mensajes.append({"role": "assistant", "content": respuesta_ia})
            
            # Mostrar en pantalla
            chat_display.append(pn.pane.Markdown(f"🤖 **Agente:** {respuesta_ia}", styles={'background': '#f0faff', 'padding': '10px', 'border-radius': '5px'}))
            
        except Exception as e:
            chat_display.append(pn.pane.Markdown(f"❌ Error: {str(e)}"))
    else:
        chat_display.append(pn.pane.Markdown("⚠️ No pude leer el prospecto."))

btn_buscar.on_click(actualizar_busqueda)
btn_preguntar.on_click(atender_chat)
btn_borrar_memoria.on_click(borrar_chat)

# --- LAYOUT ---
layout = pn.Column(
    "# 💊 Consultor con Memoria",
    pn.Row(input_med, btn_buscar),
    pn.Row("Tipo:", radio_tipo, selector_med),
    status,
    "---",
    chat_display,
    pn.Row(input_pregunta, btn_preguntar),
    btn_borrar_memoria,
    width=600
)

layout
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4c991fca-c534-4eed-b462-b112d5a2530d'>
#   <div id="cc15d447-c727-4df1-864f-2d86e3ff9268" data-root-id="4c991fca-c534-4eed-b462-b112d5a2530d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"826eb500-540f-4042-9906-dddcda7b2401":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"b2754934-1e59-4d45-b1a1-7ce17d9e326e","attributes":{"notifications":{"type":"object","name":"Notifications","id":"208b862d-e67e-4f09-85e2-8d0f04fbee06"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4c991fca-c534-4eed-b462-b112d5a2530d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"fc1b6a3c-57c9-4870-99f0-814e3ceb270f","attributes":{"plot_id":"4c991fca-c534-4eed-b462-b112d5a2530d","comm_id":"3de8e61d95364a629b4b54c216ad16c6","client_comm_id":"8ea856ef075c4a02be163639f2f710e8"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"826eb500-540f-4042-9906-dddcda7b2401","roots":{"4c991fca-c534-4eed-b462-b112d5a2530d":"cc15d447-c727-4df1-864f-2d86e3ff9268"},"root_ids":["4c991fca-c534-4eed-b462-b112d5a2530d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'21bae6b1-9203-4191-a5bd-ba89b25a1447': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto LangGraph.
#
# Como el anterior pero empleando LangGraph.

# %%
import panel as pn
import os
import requests
from bs4 import BeautifulSoup
from typing import TypedDict, Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

# Configuración inicial
from dotenv import load_dotenv
load_dotenv()
pn.extension()

# --- 1. DEFINIR EL ESTADO (La Memoria del Grafo) ---
class AgentState(TypedDict):
    # 'messages': Historial automático (se acumula)
    messages: Annotated[list, add_messages]
    # 'nregistro': El ID del medicamento seleccionado
    nregistro: str
    # 'prospecto_texto': El texto del PDF (lo guardamos aquí para no descargarlo mil veces)
    prospecto_texto: str

# --- 2. HERRAMIENTAS Y MODELO ---
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.2)

# Reutilizamos tu lógica de scraping, pero ahora es una función auxiliar
def descargar_prospecto_web(nregistro):
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:15000] # Límite para no saturar contexto
    except: return None
    return None

# --- 3. NODOS (Los pasos del proceso) ---

def nodo_gestor_contexto(state: AgentState):
    """
    Este nodo revisa si ya tenemos el prospecto. 
    Si no lo tiene, lo descarga. Si ya lo tiene, pasa al siguiente.
    """
    texto_actual = state.get("prospecto_texto")
    nreg = state.get("nregistro")
    
    # Si ya tenemos texto, no hacemos nada (ahorramos tiempo)
    if texto_actual:
        return {}
    
    # Si no, descargamos
    print(f"📥 Descargando prospecto para: {nreg}")
    nuevo_texto = descargar_prospecto_web(nreg)
    
    if not nuevo_texto:
        return {"prospecto_texto": "ERROR: No se pudo descargar el prospecto."}
    
    return {"prospecto_texto": nuevo_texto}

def nodo_bot_farmaceutico(state: AgentState):
    """
    Este nodo genera la respuesta usando el texto guardado en el estado.
    """
    contexto = state.get("prospecto_texto", "")
    mensajes = state["messages"]
    
    # Inyectamos el prospecto como System Message 'fantasma' (no se guarda en historial, solo para esta vuelta)
    prompt_sistema = SystemMessage(
        content=f"Eres un farmacéutico experto. Responde ÚNICAMENTE basándote en el siguiente prospecto:\n\n{contexto}"
    )
    
    # Llamamos a Groq con: Sistema + Historial Conversación
    respuesta = llm.invoke([prompt_sistema] + mensajes)
    
    return {"messages": [respuesta]}

# --- 4. CONSTRUIR EL GRAFO ---
workflow = StateGraph(AgentState)

# Añadimos nodos
workflow.add_node("gestor", nodo_gestor_contexto)
workflow.add_node("bot", nodo_bot_farmaceutico)

# Definimos flujo: Inicio -> Gestor (Revisar descarga) -> Bot (Responder) -> Fin
workflow.add_edge(START, "gestor")
workflow.add_edge("gestor", "bot")
workflow.add_edge("bot", END)

# Compilamos con MEMORIA (Persistence)
memory = MemorySaver()
app = workflow.compile(checkpointer=memory)

# ==========================================
# --- INTERFAZ PANEL (FRONTEND) ---
# ==========================================

# Widgets
input_med = pn.widgets.TextInput(name="1. Busca medicamento", placeholder="Ej: Paracetamol")
btn_buscar = pn.widgets.Button(name="🔍 Buscar", button_type="primary", width=100)
selector_med = pn.widgets.Select(name="2. Elige presentación", options=[])
chat_display = pn.Column(height=400, scroll=True, styles={'border': '1px solid #ccc', 'padding': '10px'})
input_pregunta = pn.widgets.TextInput(placeholder="Escribe tu duda...", width=450)
btn_preguntar = pn.widgets.Button(name="Enviar", button_type="success")
status_msg = pn.pane.Markdown("")

# Función de búsqueda (se queda igual, es auxiliar)
def buscar_api(event):
    status_msg.object = "⏳ Buscando en CIMA..."
    try:
        r = requests.get("https://cima.aemps.es/cima/rest/medicamentos", 
                         params={"nombre": input_med.value})
        res = r.json().get("resultados", [])
        selector_med.options = {m['nombre']: m['nregistro'] for m in res[:20]}
        status_msg.object = f"✅ Encontrados {len(res)} resultados."
    except:
        status_msg.object = "❌ Error en la API."

# --- FUNCIÓN CLAVE: CONECTAR PANEL CON LANGGRAPH ---
def enviar_mensaje(event):
    pregunta = input_pregunta.value
    if not pregunta: return
    
    nregistro_seleccionado = selector_med.value
    input_pregunta.value = "" # Limpiar input
    
    # 1. Mostramos mensaje usuario
    chat_display.append(pn.pane.Markdown(f"👤 **Tú:** {pregunta}"))
    chat_display.append(pn.pane.Markdown("🤖 *Escribiendo...*"))
    
    # 2. Configuración del Hilo (Sesión única por medicamento)
    # Usamos el nregistro como thread_id para que cada med tenga su chat separado
    config = {"configurable": {"thread_id": f"chat_{nregistro_seleccionado}"}}
    
    # 3. Input inicial para el Grafo
    inputs = {
        "messages": [HumanMessage(content=pregunta)], 
        "nregistro": nregistro_seleccionado 
        # Nota: 'prospecto_texto' NO se pasa aquí. El grafo ya sabe si lo tiene guardado o no.
    }
    
    # 4. EJECUTAR LANGGRAPH
    # Usamos 'invoke' (o stream) y dejamos que el grafo gestione la memoria y descarga
    resultado_final = app.invoke(inputs, config=config)
    
    # 5. Obtener respuesta
    respuesta_bot = resultado_final["messages"][-1].content
    
    # Quitar el mensaje de "escribiendo" y poner la respuesta
    chat_display.pop(-1) 
    chat_display.append(pn.pane.Markdown(f"💊 **Farmacéutico:** {respuesta_bot}", 
                                         styles={'background': '#f9f9f9', 'padding': '10px'}))

# Eventos
btn_buscar.on_click(buscar_api)
btn_preguntar.on_click(enviar_mensaje)

# Layout
layout = pn.Column(
    "# 🏥 Chat Farmacéutico (Powered by LangGraph)",
    pn.Row(input_med, btn_buscar),
    selector_med,
    status_msg,
    chat_display,
    pn.Row(input_pregunta, btn_preguntar),
    width=600
)
layout.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7bd9a6a8-115d-4f99-a72d-0ece256dd5e4'>
#   <div id="a61822f8-a830-4f72-af60-a242374744c2" data-root-id="7bd9a6a8-115d-4f99-a72d-0ece256dd5e4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"53854093-ffea-4d15-bac0-a3f6ac4e0301":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"475b3067-d218-484a-9c98-ec7512ed1bdd","attributes":{"notifications":{"type":"object","name":"Notifications","id":"28e6e978-97fb-4f30-94fc-076d55094474"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7bd9a6a8-115d-4f99-a72d-0ece256dd5e4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d3a8348b-2532-4caf-b479-84a596845343","attributes":{"plot_id":"7bd9a6a8-115d-4f99-a72d-0ece256dd5e4","comm_id":"6c4be6822f5b4cc8a48dbb8a8c08d88a","client_comm_id":"dbfa2915f6ad4349b600f525bada2a62"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"53854093-ffea-4d15-bac0-a3f6ac4e0301","roots":{"7bd9a6a8-115d-4f99-a72d-0ece256dd5e4":"a61822f8-a830-4f72-af60-a242374744c2"},"root_ids":["7bd9a6a8-115d-4f99-a72d-0ece256dd5e4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'f7ff4e27-7d49-48de-ad17-2c9af37143e9': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto LangGraph 2.
#
# Este es capaz de almacenar toda la conversación de un mismo individuo en un informe en el disco duro, una vez se reinicie el código, el agente es capaz de conservar esa información en su memoria.

# %%
import panel as pn
import os
import requests
import sqlite3
from bs4 import BeautifulSoup
from typing import TypedDict, Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

# Configuración
from dotenv import load_dotenv
load_dotenv()
pn.extension()

# --- 1. PERSISTENCIA ---
conn = sqlite3.connect("memoria_usuario.db", check_same_thread=False)
memory = SqliteSaver(conn)

# --- 2. ESTADO DEL AGENTE ---
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    nregistro: str
    prospecto_texto: str

# --- 3. LÓGICA DEL GRAFO ---
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.3)

def descargar_prospecto(nregistro):
    if not nregistro: return "No hay prospecto seleccionado."
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:12000]
    except: return "Error al descargar."
    return "No disponible."

def nodo_gestor(state: AgentState):
    # Si el prospecto ya está o es una duda general, no descargamos de nuevo
    if state.get("prospecto_texto") and len(state.get("prospecto_texto")) > 100:
        return {}
    return {"prospecto_texto": descargar_prospecto(state.get("nregistro"))}

def nodo_bot(state: AgentState):
    # PROMPT EVOLUCIONADO: Le damos permiso para usar la memoria y preguntar por la salud
    prompt_sistema = SystemMessage(content=(
        "Eres un asistente farmacéutico inteligente y atento. "
        "1. Usa el prospecto proporcionado para responder dudas técnicas.\n"
        "2. IMPORTANTE: Revisa el historial para conocer condiciones médicas del usuario (embarazo, alergias, diabetes, etc.).\n"
        "3. Si el usuario te dijo algo sobre su salud en el pasado, tenlo en cuenta para tus recomendaciones.\n"
        "4. Sé proactivo: Si hace tiempo que no se menciona una condición (como un embarazo), pregunta educadamente si esa situación continúa "
        "para poder dar el mejor consejo de seguridad.\n"
        "5. Si el medicamento es incompatible con lo que sabes del usuario, adviértelo claramente.\n\n"
        f"PROSPECTO ACTUAL:\n{state.get('prospecto_texto', 'No hay prospecto cargado.')}"
    ))
    
    respuesta = llm.invoke([prompt_sistema] + state["messages"])
    return {"messages": [respuesta]}

# --- 4. CONSTRUCCIÓN ---
builder = StateGraph(AgentState)
builder.add_node("gestor", nodo_gestor)
builder.add_node("bot", nodo_bot)
builder.add_edge(START, "gestor")
builder.add_edge("gestor", "bot")
builder.add_edge("bot", END)
app = builder.compile(checkpointer=memory)

# --- 5. INTERFAZ ---
# ID de Usuario Fijo (Esto es lo que hace que recuerde siempre)
USUARIO_ID = "usuario_maestro_01" 

input_med = pn.widgets.TextInput(name="Busca medicamento", placeholder="Ej: Ibuprofeno")
radio_tipo = pn.widgets.RadioBoxGroup(name="Tipo", options=["Marca", "Genérico (EFG)"], inline=True)
btn_buscar = pn.widgets.Button(name="🔍 Buscar", button_type="primary")
selector_med = pn.widgets.Select(name="Resultado", options={})
chat_display = pn.Column(height=450, scroll=True, styles={'background': '#f4f4f4', 'padding': '15px'})
input_pregunta = pn.widgets.TextInput(placeholder="Dime que te pasa o pregunta sobre el medicamento...")
btn_preguntar = pn.widgets.Button(name="Enviar", button_type="success")

def buscar_meds(event):
    r = requests.get("https://cima.aemps.es/cima/rest/medicamentos", params={"nombre": input_med.value})
    res = r.json().get("resultados", [])
    es_gen = "EFG" in radio_tipo.value
    filtrados = [m for m in res if ("EFG" in m['nombre'].upper()) == es_gen]
    selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados}

def chatear(event):
    pregunta = input_pregunta.value
    if not pregunta: return
    
    chat_display.append(pn.pane.Markdown(f"👤 **Tú:** {pregunta}"))
    input_pregunta.value = ""
    
    # CLAVE: Usamos siempre el mismo thread_id para el usuario
    # Así, aunque cambie el nregistro, la conversación es la misma
    config = {"configurable": {"thread_id": USUARIO_ID}}
    
    inputs = {
        "messages": [HumanMessage(content=pregunta)],
        "nregistro": selector_med.value
    }
    
    result = app.invoke(inputs, config=config)
    respuesta_final = result['messages'][-1].content
    chat_display.append(pn.pane.Markdown(f"💊 **Asistente:** {respuesta_final}"))

btn_buscar.on_click(buscar_meds)
btn_preguntar.on_click(chatear)

layout = pn.Column("# 🏥 Consultor Médico Proactivo", radio_tipo, pn.Row(input_med, btn_buscar), selector_med, chat_display, pn.Row(input_pregunta, btn_preguntar))
layout.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6fdfa032-eb15-4af6-9c5f-f30350e4fe44'>
#   <div id="e012ee98-8bf3-4181-a87f-11fa263d0559" data-root-id="6fdfa032-eb15-4af6-9c5f-f30350e4fe44" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a3ae6a9c-11f4-4b7b-a228-31d5ca81b45f":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"4fe17157-210b-4af0-a1d4-2acfc8062eed","attributes":{"notifications":{"type":"object","name":"Notifications","id":"51aed66f-0cbe-4856-af4f-263550dd2b21"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"6fdfa032-eb15-4af6-9c5f-f30350e4fe44"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"892c3dec-9733-4991-a244-292020f1e732","attributes":{"plot_id":"6fdfa032-eb15-4af6-9c5f-f30350e4fe44","comm_id":"38d7b7ae69eb4be983e04b85008ff370","client_comm_id":"4febc20a1d70485e998cc26f7e7fd17d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"a3ae6a9c-11f4-4b7b-a228-31d5ca81b45f","roots":{"6fdfa032-eb15-4af6-9c5f-f30350e4fe44":"e012ee98-8bf3-4181-a87f-11fa263d0559"},"root_ids":["6fdfa032-eb15-4af6-9c5f-f30350e4fe44"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'90c1c996-cbc9-45a2-9d87-83492f3a93f3': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto LangGraph Definitivo.
#
# Es capaz de borrar el archivo donde se guarda la información si fuese necesario.

# %%
import panel as pn
import os
import sqlite3
import requests
from bs4 import BeautifulSoup
from typing import TypedDict, Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.sqlite import SqliteSaver 
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

# Configuración inicial
from dotenv import load_dotenv
load_dotenv()
pn.extension()

# --- 1. CONFIGURACIÓN DE PERSISTENCIA ---
DB_NAME = "memoria_usuario.db"
USUARIO_ID = "usuario_maestro_01"

def inicializar_memoria():
    # Creamos la conexión y el checkpointer
    conn = sqlite3.connect(DB_NAME, check_same_thread=False)
    return conn, SqliteSaver(conn)

conn, memory = inicializar_memoria()

# --- 2. DEFINICIÓN DEL ESTADO Y GRAFO ---
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    nregistro: str
    prospecto_texto: str

llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.3)

def descargar_prospecto(nregistro):
    if not nregistro: return "No hay prospecto seleccionado."
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:12000]
    except: return "Error al descargar."
    return "No disponible."

def nodo_gestor(state: AgentState):
    if state.get("prospecto_texto") and len(state.get("prospecto_texto")) > 100:
        return {}
    return {"prospecto_texto": descargar_prospecto(state.get("nregistro"))}

def nodo_bot(state: AgentState):
    prompt_sistema = SystemMessage(content=(
        "Eres un asistente farmacéutico. Revisa el historial para conocer condiciones médicas pasadas. "
        "Si el usuario mencionó un embarazo o alergia antes, recuérdalo y advierte si el medicamento es incompatible.\n\n"
        f"PROSPECTO ACTUAL:\n{state.get('prospecto_texto', 'No hay prospecto cargado.')}"
    ))
    respuesta = llm.invoke([prompt_sistema] + state["messages"])
    return {"messages": [respuesta]}

builder = StateGraph(AgentState)
builder.add_node("gestor", nodo_gestor)
builder.add_node("bot", nodo_bot)
builder.add_edge(START, "gestor")
builder.add_edge("gestor", "bot")
builder.add_edge("bot", END)
app = builder.compile(checkpointer=memory)

# --- 3. WIDGETS DE LA INTERFAZ ---
status_msg = pn.pane.Markdown("*Sistema listo.*") # <--- Aquí está la definición que faltaba
chat_display = pn.Column(height=400, scroll=True, styles={'background': '#f9f9f9', 'padding': '10px'})
input_med = pn.widgets.TextInput(name="Busca medicamento", placeholder="Ej: Ibuprofeno")
radio_tipo = pn.widgets.RadioBoxGroup(name="Tipo", options=["Marca", "Genérico (EFG)"], inline=True)
btn_buscar = pn.widgets.Button(name="🔍 Buscar", button_type="primary")
selector_med = pn.widgets.Select(name="Resultado", options={})
input_pregunta = pn.widgets.TextInput(placeholder="Escribe tu pregunta...")
btn_preguntar = pn.widgets.Button(name="Enviar", button_type="success")

# Botones de gestión de archivo
btn_concluir = pn.widgets.Button(name="🔒 Finalizar Sesión", button_type="warning", width=150)
btn_borrar_memoria = pn.widgets.Button(name="🔥 Borrar Disco", button_type="danger", width=150)

# --- 4. LÓGICA DE INTERACCIÓN ---

def buscar_meds(event):
    status_msg.object = "⏳ Buscando..."
    r = requests.get("https://cima.aemps.es/cima/rest/medicamentos", params={"nombre": input_med.value})
    res = r.json().get("resultados", [])
    es_gen = "EFG" in radio_tipo.value
    filtrados = [m for m in res if ("EFG" in m['nombre'].upper()) == es_gen]
    selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados}
    status_msg.object = f"✅ Encontrados {len(filtrados)} resultados."

def chatear(event):
    pregunta = input_pregunta.value
    if not pregunta: return
    chat_display.append(pn.pane.Markdown(f"👤 **Tú:** {pregunta}"))
    input_pregunta.value = ""
    
    config = {"configurable": {"thread_id": USUARIO_ID}}
    result = app.invoke({"messages": [HumanMessage(content=pregunta)], "nregistro": selector_med.value}, config=config)
    
    respuesta_final = result['messages'][-1].content
    chat_display.append(pn.pane.Markdown(f"💊 **Bot:** {respuesta_final}"))

def concluir_y_liberar(event):
    global conn
    conn.close() # Cerramos la conexión para liberar el archivo
    status_msg.object = "🔒 **Conexión cerrada.** El archivo .db ya no está en uso."
    btn_preguntar.disabled = True

import gc # Garbage Collector para forzar la liberación del archivo

def borrar_y_reiniciar(event):
    global conn, memory, app
    status_msg.object = "⏳ Intentando liberar archivo..."
    
    try:
        # 1. Cerramos la conexión física
        if conn:
            conn.close()
        
        # 2. ELIMINAMOS las referencias de los objetos
        # Si no borramos 'app' y 'memory', ellos retienen el bloqueo del archivo
        del app
        del memory
        del conn
        
        # 3. Forzamos a Python a limpiar la basura
        gc.collect() 
        
        # 4. Intentamos borrar el archivo
        if os.path.exists(DB_NAME):
            os.remove(DB_NAME)
        
        # 5. RE-INICIALIZAMOS TODO desde cero
        nueva_conn = sqlite3.connect(DB_NAME, check_same_thread=False)
        nueva_memory = SqliteSaver(nueva_conn)
        
        # Actualizamos las variables globales con los nuevos objetos
        globals()['conn'] = nueva_conn
        globals()['memory'] = nueva_memory
        globals()['app'] = builder.compile(checkpointer=nueva_memory)
        
        chat_display.clear()
        btn_preguntar.disabled = False
        status_msg.object = "🔥 **Memoria de disco reseteada con éxito.**"
        
    except Exception as e:
        status_msg.object = f"❌ Error persistente: {e}\n(Prueba a pulsar 'Finalizar Sesión' primero)"

        
btn_buscar.on_click(buscar_meds)
btn_preguntar.on_click(chatear)
btn_concluir.on_click(concluir_y_liberar)
btn_borrar_memoria.on_click(borrar_y_reiniciar)

# --- 5. LAYOUT ---
layout = pn.Column(
    "# 🏥 Consultor Médico Proactivo",
    pn.Row(input_med, btn_buscar),
    pn.Row(radio_tipo, selector_med),
    status_msg,
    "---",
    chat_display,
    pn.Row(input_pregunta, btn_preguntar),
    "---",
    pn.Row(btn_concluir, btn_borrar_memoria),
    width=600
)
layout.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='37ef0295-2e3f-461b-97b9-391e75f84d52'>
#   <div id="bd767941-c89d-4646-9bcd-4d840805e337" data-root-id="37ef0295-2e3f-461b-97b9-391e75f84d52" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"49c00a82-f9c1-4b47-95f6-6e12403d585c":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"9c34592a-37e9-4b66-bd97-7621e5233390","attributes":{"notifications":{"type":"object","name":"Notifications","id":"003a9fd6-68f6-42a9-af0b-87b607ca883e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"37ef0295-2e3f-461b-97b9-391e75f84d52"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f5ac2ef8-c034-4ae6-8ef0-d060af24309e","attributes":{"plot_id":"37ef0295-2e3f-461b-97b9-391e75f84d52","comm_id":"b0157917312448c0a9dc45951535244d","client_comm_id":"7b8452c3b865469f952269c76f337207"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"49c00a82-f9c1-4b47-95f6-6e12403d585c","roots":{"37ef0295-2e3f-461b-97b9-391e75f84d52":"bd767941-c89d-4646-9bcd-4d840805e337"},"root_ids":["37ef0295-2e3f-461b-97b9-391e75f84d52"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'bd17cd97-18b2-466b-b4ef-47ba64afd697': {'version…

# %% [markdown]
# ### Agente Consultor Prospecto Pantalla Completa.

# %%
import panel as pn
import os
import sqlite3
import requests
from bs4 import BeautifulSoup
from typing import TypedDict, Annotated
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.sqlite import SqliteSaver 
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
import gc 

# --- 0. CARGA DE ENTORNO ---
load_dotenv()
pn.extension()

# Verificación de seguridad para la API KEY
if not os.environ.get("GROQ_API_KEY"):
    print("⚠️ ADVERTENCIA: No se detectó GROQ_API_KEY. Asegúrate de tener el archivo .env configurado.")

# --- 1. CONFIGURACIÓN DE PERSISTENCIA ---
DB_NAME = "memoria_usuario.db"
USUARIO_ID = "usuario_maestro_01"

def inicializar_memoria():
    # check_same_thread=False es vital para Panel + SQLite
    conn = sqlite3.connect(DB_NAME, check_same_thread=False)
    return conn, SqliteSaver(conn)

conn, memory = inicializar_memoria()

# --- 2. DEFINICIÓN DEL ESTADO Y GRAFO ---
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    nregistro: str
    prospecto_texto: str

# Modelo
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.3)

def descargar_prospecto(nregistro):
    if not nregistro: return "No hay prospecto seleccionado."
    url = f"https://cima.aemps.es/cima/dochtml/p/{nregistro}/P_{nregistro}.html"
    try:
        r = requests.get(url, timeout=10)
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            for tag in soup(["script", "style", "header", "footer", "nav"]): tag.decompose()
            return soup.get_text(separator="\n", strip=True)[:12000]
    except: return "Error al descargar prospecto."
    return "Prospecto no disponible en texto."

def nodo_gestor(state: AgentState):
    # Si ya tenemos texto, no lo descargamos otra vez
    if state.get("prospecto_texto") and len(state.get("prospecto_texto")) > 100:
        return {}
    
    # Si no, descargamos
    nuevo_texto = descargar_prospecto(state.get("nregistro"))
    return {"prospecto_texto": nuevo_texto}

def nodo_bot(state: AgentState):
    prompt_sistema = SystemMessage(content=(
        "Eres un asistente farmacéutico experto. "
        "Tu OBJETIVO PRINCIPAL es revisar el historial de chat para detectar condiciones del usuario (embarazo, hipertensión, alergias, otros medicamentos). "
        "Si detectas alguna condición previa, advierte inmediatamente si el medicamento actual es compatible o no.\n\n"
        f"--- DATOS DEL PROSPECTO ---\n{state.get('prospecto_texto', 'No cargado.')}"
    ))
    
    # Invocamos al LLM con el historial completo (state["messages"])
    respuesta = llm.invoke([prompt_sistema] + state["messages"])
    return {"messages": [respuesta]}


# Construcción del Grafo
builder = StateGraph(AgentState)
builder.add_node("gestor", nodo_gestor)
builder.add_node("bot", nodo_bot)
builder.add_edge(START, "gestor")
builder.add_edge("gestor", "bot")
builder.add_edge("bot", END)

app = builder.compile(checkpointer=memory)

# --- 3. WIDGETS DE LA INTERFAZ ---
status_msg = pn.pane.Markdown("**Estado:** Sistema listo y conectado a memoria.", styles={'color': '#666'})
chat_display = pn.Column(height=500, scroll=True, styles={'background': '#ffffff', 'border': '1px solid #eee', 'padding': '15px', 'border-radius': '8px'})

input_med = pn.widgets.TextInput(name="1. Buscar Medicamento", placeholder="Ej: Ibuprofeno")
radio_tipo = pn.widgets.RadioBoxGroup(name="Filtro", options=["Marca", "Genérico (EFG)"], inline=True)
btn_buscar = pn.widgets.Button(name="🔍 Buscar en CIMA", button_type="primary")
selector_med = pn.widgets.Select(name="2. Seleccionar Presentación", options=[])

input_pregunta = pn.widgets.TextInput(name="3. Consulta", placeholder="Ej: ¿Puedo tomarlo si soy hipertenso?")
btn_preguntar = pn.widgets.Button(name="💬 Enviar Consulta", button_type="success")

# Botones de gestión
btn_borrar_memoria = pn.widgets.Button(name="🔥 Borrar Memoria (Reset)", button_type="danger", width=200)

# --- 4. LÓGICA DE INTERACCIÓN ---

def buscar_meds(event):
    status_msg.object = "⏳ Buscando en la AEMPS..."
    try:
        r = requests.get("https://cima.aemps.es/cima/rest/medicamentos", params={"nombre": input_med.value})
        res = r.json().get("resultados", [])
        
        es_gen = "EFG" in radio_tipo.value
        if es_gen:
            filtrados = [m for m in res if "EFG" in m['nombre'].upper()]
        else:
            filtrados = [m for m in res if "EFG" not in m['nombre'].upper()]
            
        selector_med.options = {m['nombre']: m['nregistro'] for m in filtrados[:30]} # Limitamos a 30
        status_msg.object = f"✅ Encontrados {len(filtrados)} resultados."
    except Exception as e:
        status_msg.object = f"❌ Error de conexión: {str(e)}"

def chatear(event):
    pregunta = input_pregunta.value
    if not pregunta: return
    
    # 1. Mostrar mensaje usuario
    chat_display.append(pn.Row("👤", pn.pane.Markdown(f"**Tú:** {pregunta}", width=500)))
    input_pregunta.value = ""
    status_msg.object = "🤖 El agente está pensando..."

    try:
        # Configuración de hilo para SQLite
        config = {"configurable": {"thread_id": USUARIO_ID}}
        
        # 2. Invocar al grafo
        # Pasamos el nregistro actual para que el 'gestor' sepa qué descargar si hace falta
        inputs = {
            "messages": [HumanMessage(content=pregunta)], 
            "nregistro": selector_med.value
        }
        
        result = app.invoke(inputs, config=config)
        
        # 3. Mostrar respuesta bot
        respuesta_final = result['messages'][-1].content
        chat_display.append(pn.Row("💊", pn.pane.Markdown(f"**Agente:** {respuesta_final}", styles={'background': '#e6f7ff', 'padding': '10px', 'border-radius': '10px'}, width=500)))
        status_msg.object = "✅ Respuesta recibida."
        
    except Exception as e:
        status_msg.object = f"❌ Error en el Grafo: {str(e)}"

def borrar_y_reiniciar(event):
    global conn, memory, app
    status_msg.object = "⏳ Liberando base de datos..."

    try:
        if conn: conn.close()
        del app, memory, conn
        gc.collect()
        
        if os.path.exists(DB_NAME):
            os.remove(DB_NAME)
            
        # Reiniciar variables
        nueva_conn = sqlite3.connect(DB_NAME, check_same_thread=False)
        nueva_memory = SqliteSaver(nueva_conn)
        
        globals()['conn'] = nueva_conn
        globals()['memory'] = nueva_memory
        globals()['app'] = builder.compile(checkpointer=nueva_memory)
        
        chat_display.clear()
        chat_display.append(pn.pane.Markdown("✨ *Memoria borrada. Empiezas de cero.*", styles={'color': 'gray'}))
        status_msg.object = "✅ Sistema reiniciado."
        
    except Exception as e:
        status_msg.object = f"❌ Error al borrar: {e}"

# Asignar eventos
btn_buscar.on_click(buscar_meds)
btn_preguntar.on_click(chatear)
btn_borrar_memoria.on_click(borrar_y_reiniciar)

# --- 5. LAYOUT Y LANZAMIENTO WEB ---

layout = pn.Column(
    "# 🏥 Agente Farmacéutico IA",
    pn.Row(input_med, btn_buscar),
    pn.Row(radio_tipo, selector_med),
    status_msg,
    "---",
    chat_display,
    pn.Row(input_pregunta, btn_preguntar),
    "---",
    btn_borrar_memoria,
    width=700
)

# ESTA ES LA PARTE IMPORTANTE PARA QUE SE ABRA EN EL NAVEGADOR
if __name__ == "__main__":
    # show=True abre la pestaña automáticamente
    pn.serve(layout, show=True, port=5006)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6e8d1da7-275e-4382-8903-4cb1b6f9891e'>
#   <div id="f889dfe0-f5eb-497b-b787-5e549b5b0af6" data-root-id="6e8d1da7-275e-4382-8903-4cb1b6f9891e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"cc9ea7cf-34ce-4a27-89c4-038545d390fd":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"c19c7cdb-ccf9-4703-84e5-da76b2733b98","attributes":{"notifications":{"type":"object","name":"Notifications","id":"1186008f-18b5-43d3-96dd-40614636a99f"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"6e8d1da7-275e-4382-8903-4cb1b6f9891e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9d4452f8-a766-44a6-8ad7-8dae375245fb","attributes":{"plot_id":"6e8d1da7-275e-4382-8903-4cb1b6f9891e","comm_id":"5b339fc6e95c4b81ac914563513f35ba","client_comm_id":"748e950029b64e9e85644c681787967f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"cc9ea7cf-34ce-4a27-89c4-038545d390fd","roots":{"6e8d1da7-275e-4382-8903-4cb1b6f9891e":"f889dfe0-f5eb-497b-b787-5e549b5b0af6"},"root_ids":["6e8d1da7-275e-4382-8903-4cb1b6f9891e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Launching server at http://localhost:5006

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.54.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=5.5 (from streamlit)
#   Downloading cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (8.3.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (26.0)
# Collecting pandas<3,>=1.4.0 (from streamlit)
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (11.1.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (6.33.5)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-23.0.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (9.1.4)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.16.0)
# Requirement already satisfied: colorama in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\manue\anaconda3\envs\pytorch_gpu\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.54.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.1 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.1 MB 8.0 MB/s eta 0:00:01
#    ------------------- -------------------- 4.5/9.1 MB 8.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.8/9.1 MB 7.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 7.4 MB/s  0:00:01
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB 6.8 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.6-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.3 MB 9.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.3 MB 8.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.3 MB 8.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.3 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.3 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.3 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 8.8 MB/s  0:00:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/6.9 MB 7.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.9 MB 8.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.9 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 8.7 MB/s  0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading pyarrow-23.0.1-cp311-cp311-win_amd64.whl (27.5 MB)
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.6/27.5 MB 9.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 3.4/27.5 MB 8.8 MB/s eta 0:00:03
#    ------- -------------------------------- 5.2/27.5 MB 8.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 7.1/27.5 MB 8.7 MB/s eta 0:00:03
#    ------------ --------------------------- 8.9/27.5 MB 8.7 MB/s eta 0:00:03
#    --------------- ------------------------ 10.7/27.5 MB 8.8 MB/s eta 0:00:02
#    ------------------ --------------------- 12.6/27.5 MB 8.8 MB/s eta 0:00:02
#    --------------------- ------------------ 14.7/27.5 MB 8.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 16.3/27.5 MB 8.7 MB/s eta 0:00:02
#    -------------------------- ------------- 18.4/27.5 MB 8.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.9/27.5 MB 8.7 MB/s eta 0:00:01
#    ------------------------------- -------- 21.5/27.5 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 22.8/27.5 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.1/27.5 MB 8.2 MB/s eta 0:00:01
#    ------------------------------------ --- 25.4/27.5 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.5 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 27.5/27.5 MB 7.9 MB/s  0:00:03
# Installing collected packages: watchdog, toml, smmap, pyarrow, cachetools, blinker, pydeck, pandas, gitdb, gitpython, altair, streamlit
#
#    --- ------------------------------------  1/12 [toml]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------- -----------------------------  3/12 [pyarrow]
#    ---------------- -----------------------  5/12 [blinker]
#    -------------------- -------------------  6/12 [pydeck]
#   Attempting uninstall: pandas
#    -------------------- -------------------  6/12 [pydeck]
#    ----------------------- ----------------  7/12 [pandas]
#     Found existing installation: pandas 3.0.0
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#     Uninstalling pandas-3.0.0:
#    ----------------------- ----------------  7/12 [pandas]
#       Successfully uninstalled pandas-3.0.0
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ----------------------- ----------------  7/12 [pandas]
#    ------------------------------ ---------  9/12 [gitpython]
#    --------------------------------- ------ 10/12 [altair]
#    --------------------------------- ------ 10/12 [altair]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ------------------------------------ --- 11/12 [streamlit]
#    ---------------------------------------- 12/12 [streamlit]
#
# Successfully installed altair-6.0.0 blinker-1.9.0 cachetools-6.2.6 gitdb-4.0.12 gitpython-3.1.46 pandas-2.3.3 pyarrow-23.0.1 pydeck-0.9.1 smmap-5.0.2 streamlit-1.54.0 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.
